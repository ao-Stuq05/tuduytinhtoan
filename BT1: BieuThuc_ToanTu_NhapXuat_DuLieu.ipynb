# %%
#W2A1
print("Hello World!")
# Out:
# Hello World!

# %%
#W2A2
name = input("What's your name: ")
print(f"Welcome {name}! ")
# Out:
# What's your name: Thu Hien
# Welcome Thu Hien!

# %%
#W2A3
a = int(input("Number a: "))
b = int(input("Numbet b: "))
print(f("a+b = {a+b}"))
print(f("a-b = {a-b}"))
print(f())

# %%
#W2A4
a1, b1, c1, a2, b2, a3 = map(int, input("Nhập số: ").split())
trungbinh = ((a1 + b1 + c1) + (a2 + b2)*2 + a3 *3)/10
print("TB: ", f"{trungbinh: .1f}")
# Out:
# Nhập số: 1 2 3 4 5 6
# TB:   4.2

# %%
#W2A5
a, b = map(int, input("nhap hai so a, b: ").split())
print("a mu b bang ", a ** b)
# Out:
# nhap hai so a, b: 2 3
# a mu b bang  8

# %%
#W2A6
x = input()
print(ord(x))
print(chr(ord(x) - 32))
# Out:
# a
# 97
# A

# %%
#W2A7
print(((13 ** 2) * 3) + 5)
print(13**2*3 + 5)
# Out:
# 512
# 512

# %%
#W2A8
print(f"Temperature (F): {((float(input("Temperature (C): "))*9/5) + 32):.2f}")
# Out:
# Temperature (C): 36
# Temperature (F): 96.80

# %%
#W2A9
x = float(input("The price of the watch: "))
print(f'{(x+10 + x*0.4):.2f}')
# Out:
# The price of the watch: 54.7
# 86.58

# %%
#W2A10
name1, name2, name3 = input("Who: ").split()
print(f"Hiiii {name1}, {name2} and {name3}! :)")
# Out:
# Who: eren mikasa armin
# Hiiii eren, mikasa and armin! :)

# %%
#W2A11
hour, min = map(int, input("Enter hour and minute: ").split())
print("Hour to second: ", hour*3600, "\nMinute to second: ", min*60)
# Out:
# Enter hour and minute: 5 4
# Hour to second:  18000
# Minute to second:  240

# %%
#W2A12
n = int(input())
res = n*n*6
print(res)
# Out:
# 6
# 216

# %%
#W2A13
num1, num2 = map(int, input().split())
print((num1 * num2) % 10)
# Out:
# 2 7
# 4

# %%
#W2A14
a,b = map(int,input().split())
a=int(input())
a,b =b,a
print(a,b)
# Out:
# 3 4
# 4 3

# %%
#W2A15
n = int(input("n: "))
so_sao = 6*n*(n-1) + 1
print("Số sao thứ ", n, ": ", so_sao)
# Out:
# n: 3
# Số sao thứ  3 :  37

# %%
#W2A16
print("Spring")
print("Summer")
print ("Autumn")
print("Winter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
for i in range(1, 6, 2):
    print("*"*i)
# Out:
# *
# ***
# *****

# %%
#W2A18
print("""### # #  ### ###
 #  #  #  #   #
 #  #  #  #   #
 #  #  #  #   #
 #  # #   #   # """)
# Out:
# ### # #  ### ###
#  #  #  #  #   #
#  #  #  #  #   #
#  #  #  #  #   #
#  #  # #   #   #

# %%
#W2A19
print("Monday \nTuesday \nWesday \nThursday \nFriday \nSartuday \nSunday")
# Out:
# Monday
# Tuesday
# Wesday
# Thursday
# Friday
# Sartuday
# Sunday

# %%
#W2A20
print("""January
February
March
April
May
June
July
August
September
October
November
December""")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
for i in range(1, 10, 1):
  print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
